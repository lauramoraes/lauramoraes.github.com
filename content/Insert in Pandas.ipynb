# %%
import pandas

# %% [markdown]
# ### Testando como fica o Markdown em blog
# 1. Lista de coisa
# 2. Continuando a lista

# %%
df = pandas.read_pickle('cities.p')

# %%
df
# Out:
#                                            latitude  longitude short_name
# city                   state
# atlântida              rio grande do sul -29.786145 -50.032883         RS
# santa cruz do sul      rio grande do sul -29.719768 -52.429929         RS
# lajeado                rio grande do sul -29.465454 -51.967828         RS
# eldorado do sul        rio grande do sul -29.999293 -51.310419         RS
# alvorada               rio grande do sul -29.997493 -51.077729         RS
# canoas                 rio grande do sul -29.918697 -51.181030         RS
# portão                 rio grande do sul -29.696259 -51.230150         RS
# novo hamburgo          rio grande do sul -29.686326 -51.128605         RS
# dois irmãos            rio grande do sul -29.584159 -51.087619         RS
# bento gonçalves        rio grande do sul -29.167402 -51.515560         RS
# gravataí               rio grande do sul -29.945519 -50.990793         RS
# ...

# %%
df.loc['rio de janeiro', 'rio de janeiro']
# Out:
# latitude     -22.8767
# longitude    -43.2279
# short_name         RJ
# Name: (rio de janeiro, rio de janeiro), dtype: object

# %%
list1 = [{'city': u'armação de búzios', 'state': u'rio de janeiro', "latitude":-22.772106 ,'longitude':-41.9715504 , 'short_name': u'RJ'},
         {'city': u'águas de lindóia', 'state': u'são paulo', "latitude":-22.4748845 ,'longitude':-46.6413143 , 'short_name': u'SP'}]

# %%
df2 = pandas.DataFrame.from_dict(list1, orient='columns').set_index(['city', 'state'])

# %%
df3 = pandas.concat([df,df2], 0)

# %%
df3.to_pickle('cities.p')

# %%
from IPython.core.display import display, HTML
display(HTML('<h1>Hello, world!</h1>'))
# Out:
# <h1>Hello, world!</h1>

# %% [raw]
# <center><iframe src="https://www.desmos.com/calculator/ob9evnsqys?embed" width="500px" height="500px" style="border: 1px solid #ccc" frameBorder=0 /></center>
